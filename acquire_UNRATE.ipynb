# %% [markdown]
# <a href="https://colab.research.google.com/github/CuiyingLin17/IS477BusinessCoders/blob/main/acquire_UNRATE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
import hashlib

# %%
os.makedirs("data/raw", exist_ok=True)

unrate_url ="https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23ebf3fb&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1320&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=UNRATE&scale=left&cosd=1948-01-01&coed=2026-03-01&line_color=%230073e6&link_values=false&line_style=solid&mark_type=none&mw=3&lw=3&ost=-99999&oet=99999&mma=0&fml=a&fq=Monthly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2026-04-05&revision_date=2026-04-05&nd=1948-01-01"
unrate_filename = "UNRATE.csv"

response = requests.get(unrate_url)

with open(unrate_filename, "wb") as f:
    f.write(response.content)

print("Saved UNRATE dataset:", unrate_filename)
# Out:
# Saved UNRATE dataset: UNRATE.csv

# %%
def sha256(path):
    with open(path, "rb") as f:
        return hashlib.sha256(f.read()).hexdigest()

print("UNRATE SHA-256:", sha256(unrate_filename))
# Out:
# UNRATE SHA-256: 084d2f0cfe41575534b96bd51b88c6e93ddc8d5f0eca7e470ecfd19f5428c94f

# %%
import pandas as pd

# %%
df = pd.read_csv(unrate_filename)
df.head()
# Out:
#   observation_date  UNRATE
# 0       1948-01-01     3.4
# 1       1948-02-01     3.8
# 2       1948-03-01     4.0
# 3       1948-04-01     3.9
# 4       1948-05-01     3.5

# %%
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
print("\nData types:")
print(df.dtypes)
# Out:
# Shape: (939, 2)
# Columns: ['observation_date', 'UNRATE']
#
# Data types:
# observation_date     object
# UNRATE              float64
# dtype: object

# %%
print("Missing values:")
print(df.isna().sum())

print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Missing values:
# observation_date    0
# UNRATE              1
# dtype: int64
#
# Duplicate rows: 0

# %%
df[df.columns[0]] = pd.to_datetime(df[df.columns[0]], errors="coerce")
df = df[(df["observation_date"] >= '2015-01-01') & (df["observation_date"] <= '2026-01-01')]
print("Date range:", df[df.columns[0]].min(), "to", df[df.columns[0]].max())
# Out:
# Date range: 2015-01-01 00:00:00 to 2026-01-01 00:00:00

# %%
df.head()
# Out:
#     observation_date  UNRATE
# 804       2015-01-01     5.7
# 805       2015-02-01     5.5
# 806       2015-03-01     5.4
# 807       2015-04-01     5.4
# 808       2015-05-01     5.6
