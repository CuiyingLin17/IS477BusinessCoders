# %% [markdown]
# <a href="https://colab.research.google.com/github/CuiyingLin17/IS477BusinessCoders/blob/main/acquire_CPIAUCSL_assess1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
import hashlib

# %%
os.makedirs("data/raw", exist_ok=True)

CPIAUCSL_url = "https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23ebf3fb&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1320&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=CPIAUCSL&scale=left&cosd=1947-01-01&coed=2026-02-01&line_color=%230073e6&link_values=false&line_style=solid&mark_type=none&mw=3&lw=3&ost=-99999&oet=99999&mma=0&fml=a&fq=Monthly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=lin&vintage_date=2026-04-05&revision_date=2026-04-05&nd=1947-01-01"
CPIAUCSL_filename = "CPIAUCSL.csv"

response = requests.get(CPIAUCSL_url)

with open(CPIAUCSL_filename, "wb") as f:
    f.write(response.content)

print("Saved CPIAUCSL dataset:", CPIAUCSL_filename)

# %%
def sha256(path):
    with open(path, "rb") as f:
        return hashlib.sha256(f.read()).hexdigest()

print("UNRATE SHA-256:", sha256(CPIAUCSL_filename))
# Out:
# Saved CPIAUCSL dataset: CPIAUCSL.csv
# UNRATE SHA-256: 4494d9e15555069f0721bf5d18062bd7f88b70e3736ac5da2d5fcaf9ac64cd40

# %%
import pandas as pd
df = pd.read_csv(CPIAUCSL_filename)
df.head()
# Out:
#   observation_date  CPIAUCSL
# 0       1947-01-01     21.48
# 1       1947-02-01     21.62
# 2       1947-03-01     22.00
# 3       1947-04-01     22.00
# 4       1947-05-01     21.95

# %%
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
print("\nData types:")
print(df.dtypes)
# Out:
# Shape: (950, 2)
# Columns: ['observation_date', 'CPIAUCSL']
#
# Data types:
# observation_date     object
# CPIAUCSL            float64
# dtype: object

# %%
print("Missing values:")
print(df.isna().sum())

print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Missing values:
# observation_date    0
# CPIAUCSL            1
# dtype: int64
#
# Duplicate rows: 0

# %%
df[df.columns[0]] = pd.to_datetime(df[df.columns[0]], errors="coerce")
df = df[(df["observation_date"] >= '2015-01-01') & (df["observation_date"] <= '2026-01-01')]
print("Date range:", df[df.columns[0]].min(), "to", df[df.columns[0]].max())
# Out:
# Date range: 2015-01-01 00:00:00 to 2026-01-01 00:00:00

# %%
df['OLD_CPI'] = df['CPIAUCSL'].shift(1)
df['Inflation_Rate'] = (df['CPIAUCSL'] - df['OLD_CPI']) / df['OLD_CPI'] * 100
df = df.drop(columns=['OLD_CPI'])

# %%
df.head()
# Out:
#     observation_date  CPIAUCSL  Inflation_Rate
# 816       2015-01-01   234.747             NaN
# 817       2015-02-01   235.342        0.253464
# 818       2015-03-01   235.976        0.269395
# 819       2015-04-01   236.222        0.104248
# 820       2015-05-01   237.001        0.329775
